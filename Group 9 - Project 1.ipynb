# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import folium
from IPython.display import display
from statsmodels.graphics.tsaplots import plot_pacf
from matplotlib.pylab import rcParams
from statsmodels.tsa.arima.model import ARIMA
import statsmodels.api as sm
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
#Task 1
crime_df = pd.read_csv('Crime_Data_from_2020_to_Present.csv',na_values=["-"])
crime_df
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0        10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230
# 1       190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330
# 2       200110444  04/14/2020 12:00:00 AM  02/13/2020 12:00:00 AM      1200
# 3       191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730
# 4       191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415
# ...           ...                     ...                     ...       ...
# 815877  231604807  01/27/2023 12:00:00 AM  01/26/2023 12:00:00 AM      1800
# 815878  231606525  03/22/2023 12:00:00 AM  03/22/2023 12:00:00 AM      1000
# 815879  231210064  04/12/2023 12:00:00 AM  04/12/2023 12:00:00 AM      1630
# 815880  230115220  07/02/2023 12:00:00 AM  07/01/2023 12:00:00 AM         1
# 815881  230906458  03/05/2023 12:00:00 AM  03/05/2023 12:00:00 AM       900
#
#         AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0          3    Southwest          377         2     624
# 1          1      Central          163         2     624
# 2          1      Central          155         2     845
# 3         15  N Hollywood         1543         2     745
# 4         19      Mission         1998         2     740
# ...      ...          ...          ...       ...     ...
# 815877    16     Foothill         1663         2     740
# 815878    16     Foothill         1602         1     230
# 815879    12  77th Street         1239         1     230
# 815880     1      Central          154         1     352
# 815881     9     Van Nuys          914         2     745
#
#                                               Crm Cd Desc  ... Status  \
# 0                                BATTERY - SIMPLE ASSAULT  ...     AO
# 1                                BATTERY - SIMPLE ASSAULT  ...     IC
# 2               SEX OFFENDER REGISTRANT OUT OF COMPLIANCE  ...     AA
# 3                VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...     IC
# 4       VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...     IC
# ...                                                   ...  ...    ...
# 815877  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...     IC
# 815878     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...     IC
# 815879     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...     IC
# 815880                                         PICKPOCKET  ...     IC
# 815881           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...     IC
#
#          Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0        Adult Other    624.0      NaN       NaN      NaN
# 1        Invest Cont    624.0      NaN       NaN      NaN
# 2       Adult Arrest    845.0      NaN       NaN      NaN
# 3        Invest Cont    745.0    998.0       NaN      NaN
# 4        Invest Cont    740.0      NaN       NaN      NaN
# ...              ...      ...      ...       ...      ...
# 815877   Invest Cont    740.0      NaN       NaN      NaN
# 815878   Invest Cont    230.0      NaN       NaN      NaN
# 815879   Invest Cont    230.0      NaN       NaN      NaN
# 815880   Invest Cont    352.0      NaN       NaN      NaN
# 815881   Invest Cont    745.0      NaN       NaN      NaN
#
#                                         LOCATION Cross Street      LAT  \
# 0        1100 W  39TH                         PL          NaN  34.0141
# 1         700 S  HILL                         ST          NaN  34.0459
# 2         200 E  6TH                          ST          NaN  34.0448
# 3        5400    CORTEEN                      PL          NaN  34.1685
# 4       14400    TITUS                        ST          NaN  34.2198
# ...                                          ...          ...      ...
# 815877  12500    BRANFORD                     ST          NaN  34.2466
# 815878  12800    FILMORE                      ST          NaN  34.2790
# 815879   6100 S  VERMONT                      AV          NaN  33.9841
# 815880    500 S  MAIN                         ST          NaN  34.0467
# 815881  14500    HARTLAND                     ST          NaN  34.1951
#
#              LON
# 0      -118.2978
# 1      -118.2545
# 2      -118.2474
# 3      -118.4019
# 4      -118.4468
# ...          ...
# 815877 -118.4054
# 815878 -118.4116
# 815879 -118.2915
# 815880 -118.2485
# 815881 -118.4487
#
# [815882 rows x 28 columns]

# %%
#Task 2
#2.1
crime_df.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0   10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230     3
# 1  190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330     1
# 2  200110444  04/14/2020 12:00:00 AM  02/13/2020 12:00:00 AM      1200     1
# 3  191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730    15
# 4  191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415    19
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0    Southwest          377         2     624
# 1      Central          163         2     624
# 2      Central          155         2     845
# 3  N Hollywood         1543         2     745
# 4      Mission         1998         2     740
#
#                                          Crm Cd Desc  ... Status  \
# 0                           BATTERY - SIMPLE ASSAULT  ...     AO
# 1                           BATTERY - SIMPLE ASSAULT  ...     IC
# 2          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE  ...     AA
# 3           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...     IC
# 4  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...     IC
#
#     Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0   Adult Other    624.0      NaN       NaN      NaN
# 1   Invest Cont    624.0      NaN       NaN      NaN
# 2  Adult Arrest    845.0      NaN       NaN      NaN
# 3   Invest Cont    745.0    998.0       NaN      NaN
# 4   Invest Cont    740.0      NaN       NaN      NaN
#
#                                    LOCATION Cross Street      LAT       LON
# 0   1100 W  39TH                         PL          NaN  34.0141 -118.2978
# 1    700 S  HILL                         ST          NaN  34.0459 -118.2545
# 2    200 E  6TH                          ST          NaN  34.0448 -118.2474
# 3   5400    CORTEEN                      PL          NaN  34.1685 -118.4019
# 4  14400    TITUS                        ST          NaN  34.2198 -118.4468
#
# [5 rows x 28 columns]

# %%
#2.2
crime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 815882 entries, 0 to 815881
# Data columns (total 28 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DR_NO           815882 non-null  int64
#  1   Date Rptd       815882 non-null  object
#  2   DATE OCC        815882 non-null  object
#  3   TIME OCC        815882 non-null  int64
#  4   AREA            815882 non-null  int64
#  5   AREA NAME       815882 non-null  object
#  6   Rpt Dist No     815882 non-null  int64
#  7   Part 1-2        815882 non-null  int64
#  8   Crm Cd          815882 non-null  int64
#  9   Crm Cd Desc     815882 non-null  object
#  10  Mocodes         703120 non-null  object
#  11  Vict Age        815882 non-null  int64
#  12  Vict Sex        708689 non-null  object
#  13  Vict Descent    708680 non-null  object
#  14  Premis Cd       815873 non-null  float64
#  15  Premis Desc     815402 non-null  object
#  16  Weapon Used Cd  284434 non-null  float64
#  17  Weapon Desc     284434 non-null  object
#  18  Status          815882 non-null  object
#  19  Status Desc     815882 non-null  object
#  20  Crm Cd 1        815872 non-null  float64
#  21  Crm Cd 2        60117 non-null   float64
#  22  Crm Cd 3        2013 non-null    float64
#  23  Crm Cd 4        59 non-null      float64
#  24  LOCATION        815882 non-null  object
#  25  Cross Street    130521 non-null  object
#  26  LAT             815882 non-null  float64
#  27  LON             815882 non-null  float64
# dtypes: float64(8), int64(7), object(13)
# memory usage: 174.3+ MB

# %%
#2.3
print(crime_df.columns)
# Out:
# Index(['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME',
#        'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Mocodes',
#        'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc',
#        'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'Crm Cd 1',
#        'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'LOCATION', 'Cross Street', 'LAT',
#        'LON'],
#       dtype='object')

# %%
#2.3
crime_df.describe()
# Out:
#               DR_NO       TIME OCC           AREA    Rpt Dist No  \
# count  8.158820e+05  815882.000000  815882.000000  815882.000000
# mean   2.160434e+08    1335.614658      10.711521    1117.576886
# std    1.080151e+07     654.102822       6.092813     609.276287
# min    8.170000e+02       1.000000       1.000000     101.000000
# 25%    2.101222e+08     900.000000       6.000000     621.000000
# 50%    2.201145e+08    1415.000000      11.000000    1142.000000
# 75%    2.219155e+08    1900.000000      16.000000    1617.000000
# max    2.399165e+08    2359.000000      21.000000    2199.000000
#
#             Part 1-2         Crm Cd       Vict Age      Premis Cd  \
# count  815882.000000  815882.000000  815882.000000  815873.000000
# mean        1.413928     500.777800      29.818963     305.776683
# std         0.492536     207.816937      21.772828     216.646998
# min         1.000000     110.000000      -3.000000     101.000000
# 25%         1.000000     331.000000       8.000000     101.000000
# 50%         1.000000     442.000000      31.000000     203.000000
# 75%         2.000000     626.000000      45.000000     501.000000
# max         2.000000     956.000000     120.000000     976.000000
#
#        Weapon Used Cd       Crm Cd 1      Crm Cd 2     Crm Cd 3    Crm Cd 4  \
# count   284434.000000  815872.000000  60117.000000  2013.000000   59.000000
# mean       362.906165     500.515309    957.447245   983.647293  990.627119
# std        123.759695     207.605385    111.527047    52.758676   28.131402
# min        101.000000     110.000000    210.000000   310.000000  821.000000
# 25%        310.000000     331.000000    998.000000   998.000000  998.000000
# 50%        400.000000     442.000000    998.000000   998.000000  998.000000
# 75%        400.000000     626.000000    998.000000   998.000000  998.000000
# max        516.000000     956.000000    999.000000   999.000000  999.000000
#
#                  LAT            LON
# count  815882.000000  815882.000000
# mean       33.800054    -117.404189
# std         3.042256      10.560763
# min         0.000000    -118.667600
# 25%        34.011700    -118.429100
# 50%        34.057900    -118.320500
# 75%        34.162900    -118.273900
# max        34.334300       0.000000

# %%
# Task 3
# 3.1 
crime_df.isnull().sum()
# Out:
# DR_NO                  0
# Date Rptd              0
# DATE OCC               0
# TIME OCC               0
# AREA                   0
# AREA NAME              0
# Rpt Dist No            0
# Part 1-2               0
# Crm Cd                 0
# Crm Cd Desc            0
# Mocodes           112762
# Vict Age               0
# Vict Sex          107193
# Vict Descent      107202
# Premis Cd              9
# Premis Desc          480
# Weapon Used Cd    531448
# Weapon Desc       531448
# Status                 0
# Status Desc            0
# Crm Cd 1              10
# Crm Cd 2          755765
# Crm Cd 3          813869
# Crm Cd 4          815823
# LOCATION               0
# Cross Street      685361
# LAT                    0
# LON                    0
# dtype: int64

# %%
# Removing Crm Cd 2, Crm Cd 3, Crm Cd 4, Cross Street columns as more than 60% of them are empty
crime_df.drop(labels=['Crm Cd 2','Crm Cd 3','Crm Cd 4','Cross Street','Mocodes','Weapon Used Cd', 'Weapon Desc'], axis=1, inplace=True)
# Removing observations where Premis Cd, Premis Desc, Crm Cd 1
crime_df.dropna(subset=['Premis Cd','Premis Desc','Crm Cd 1'], inplace = True)

# %%
# Imputation of Nulls
crime_df['Vict Sex'].fillna('X', inplace = True)
crime_df['Vict Descent'].fillna('X', inplace = True)

# %%
# 3.2 Duplicates
crime_df[crime_df.duplicated()] # no duplicates
# Out:
# Empty DataFrame
# Columns: [DR_NO, Date Rptd, DATE OCC, TIME OCC, AREA, AREA NAME, Rpt Dist No, Part 1-2, Crm Cd, Crm Cd Desc, Vict Age, Vict Sex, Vict Descent, Premis Cd, Premis Desc, Status, Status Desc, Crm Cd 1, LOCATION, LAT, LON]
# Index: []
#
# [0 rows x 21 columns]

# %%
# 3.3 Converting datatypes to datetime
crime_df["Date Rptd"]= crime_df["Date Rptd"].str.replace(' 12:00:00 AM','')
crime_df["DATE OCC"]= crime_df["DATE OCC"].str.replace(' 12:00:00 AM','')

# %%
crime_df['Date Rptd'] = pd.to_datetime(crime_df['Date Rptd'], format= '%m/%d/%Y')
crime_df['DATE OCC'] = pd.to_datetime(crime_df['DATE OCC'],format= '%m/%d/%Y')
# Data type conversion (Note- Did not do weapon used cd because of nulls)
crime_df[['Premis Cd','Crm Cd 1']] = crime_df[['Premis Cd','Crm Cd 1']].astype(int)

# %%
crime_df['year occured'] = crime_df['DATE OCC'].dt.year
crime_df['month occured'] = crime_df['DATE OCC'].dt.month

# %%
crime_df = crime_df.set_index('DATE OCC').sort_index()

# %%
crime_df.isnull().sum()
# Out:
# DR_NO            0
# Date Rptd        0
# TIME OCC         0
# AREA             0
# AREA NAME        0
# Rpt Dist No      0
# Part 1-2         0
# Crm Cd           0
# Crm Cd Desc      0
# Vict Age         0
# Vict Sex         0
# Vict Descent     0
# Premis Cd        0
# Premis Desc      0
# Status           0
# Status Desc      0
# Crm Cd 1         0
# LOCATION         0
# LAT              0
# LON              0
# year occured     0
# month occured    0
# dtype: int64

# %%
crime_df.describe().apply(lambda x:x.apply('{0:.5f}'.format))
# Out:
#                  DR_NO      TIME OCC          AREA   Rpt Dist No  \
# count     815392.00000  815392.00000  815392.00000  815392.00000
# mean   216040996.91677    1335.78911      10.71112    1117.53825
# std     10801207.31080     653.98032       6.09326     609.32190
# min          817.00000       1.00000       1.00000     101.00000
# 25%    210122110.75000     900.00000       6.00000     621.00000
# 50%    220114439.50000    1415.00000      11.00000    1142.00000
# 75%    221915400.25000    1900.00000      16.00000    1617.00000
# max    239916487.00000    2359.00000      21.00000    2199.00000
#
#            Part 1-2        Crm Cd      Vict Age     Premis Cd      Crm Cd 1  \
# count  815392.00000  815392.00000  815392.00000  815392.00000  815392.00000
# mean        1.41411     500.86545      29.82875     305.72867     500.60465
# std         0.49257     207.80863      21.77060     216.68018     207.59761
# min         1.00000     110.00000      -3.00000     101.00000     110.00000
# 25%         1.00000     331.00000       8.00000     101.00000     331.00000
# 50%         1.00000     442.00000      31.00000     203.00000     442.00000
# 75%         2.00000     626.00000      45.00000     501.00000     626.00000
# max         2.00000     956.00000     120.00000     971.00000     956.00000
#
#                 LAT           LON  year occured month occured
# count  815392.00000  815392.00000  815392.00000  815392.00000
# mean       33.79994    -117.40377    2021.46637       6.23975
# std         3.04293      10.56311       1.07776       3.33748
# min         0.00000    -118.66760    2020.00000       1.00000
# 25%        34.01170    -118.42910    2021.00000       3.00000
# 50%        34.05790    -118.32050    2021.00000       6.00000
# 75%        34.16290    -118.27390    2022.00000       9.00000
# max        34.33430       0.00000    2023.00000      12.00000

# %%
# Make age a positive number
crime_df['Vict Age'] = crime_df['Vict Age'].abs()

# %%
# Replacing H Sex with X
crime_df['Vict Sex']=crime_df['Vict Sex'].replace('H','X')

# %%
crime_df.columns
# Out:
# Index(['DR_NO', 'Date Rptd', 'TIME OCC', 'AREA', 'AREA NAME', 'Rpt Dist No',
#        'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Vict Age', 'Vict Sex',
#        'Vict Descent', 'Premis Cd', 'Premis Desc', 'Status', 'Status Desc',
#        'Crm Cd 1', 'LOCATION', 'LAT', 'LON', 'year occured', 'month occured'],
#       dtype='object')

# %% [markdown]
# ## EDA

# %%
# 1. Crime Trend 
crime_count = crime_df.groupby(crime_df.index.date).size().reset_index()

# %%
crime_count.rename(columns={'index':'Date',0:'crime_count'}, inplace=True)
crime_count['Date']= pd.to_datetime(crime_count['Date'],format='%Y-%m-%d')
crime_count.set_index('Date',inplace=True)

# %%
crime_count.head()
# Out:
#             crime_count
# Date
# 2020-01-01         1105
# 2020-01-02          526
# 2020-01-03          595
# 2020-01-04          540
# 2020-01-05          505

# %%
monthly_crime_count = crime_count.resample('MS').mean()

# %%
monthly_crime_count.head()
# Out:
#             crime_count
# Date
# 2020-01-01   595.903226
# 2020-02-01   594.620690
# 2020-03-01   521.000000
# 2020-04-01   522.366667
# 2020-05-01   554.419355

# %%
fig, ax = plt.subplots(1,1, figsize= (10,6))

avg = monthly_crime_count['crime_count'].sum()/len(monthly_crime_count)
avg = [avg]*len(monthly_crime_count)

ax.plot(monthly_crime_count, label ='Monthly Crime Count')
ax.plot(monthly_crime_count.index,avg,linestyle= '--', label='Avg Crime')

fig.suptitle('Los Angeles Crime Trend')

ax.legend()

# %%
# 2. Seasonal Patterns
avg_crimes_per_month = crime_df.groupby(['year occured','month occured']).size().groupby('month occured').mean().reset_index()
avg_crimes_per_month.columns=['month occured','average crimes per month']
avg_crimes_per_month
# Out:
#     month occured  average crimes per month
# 0               1              18239.500000
# 1               2              17135.250000
# 2               3              17771.750000
# 3               4              17538.750000
# 4               5              18298.000000
# 5               6              18174.000000
# 6               7              18802.250000
# 7               8              18659.500000
# 8               9              17717.250000
# 9              10              14955.500000
# 10             11              17507.000000
# 11             12              17901.333333

# %%
sns.countplot(data=crime_df, x='month occured', hue='year occured')
y=avg_crimes_per_month['average crimes per month']
plt.plot(y, marker='.', color='black', linestyle='--', label='Average')
plt.legend(title='Year', loc='center left', bbox_to_anchor=(1, 0.85))
plt.xlabel("Month")
plt.ylabel("Count of crimes")
plt.title("Crimes grouped by month and year")
plt.show()

# %%
# 3. Common crime type
print(crime_df[['Crm Cd Desc','Crm Cd']].value_counts())
top_crimes=crime_df['Crm Cd Desc'].value_counts().head(10)
sns.countplot(data=crime_df[crime_df['Crm Cd Desc'].isin(top_crimes.index)], y='Crm Cd Desc', order=top_crimes.index)
plt.xlabel("Count of crimes")
plt.ylabel("Crime Types")
plt.title("Top 10 crimes")
print("\033[1mMost common crime type observed is:  " , top_crimes.head(1)," \033[0m")
# Out:
# Crm Cd Desc                                              Crm Cd
# VEHICLE - STOLEN                                         510       87354
# BATTERY - SIMPLE ASSAULT                                 624       64929
# THEFT OF IDENTITY                                        354       51723
# BURGLARY FROM VEHICLE                                    330       49995
# VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)  740       49748
#                                                                    ...
# GRAND THEFT / AUTO REPAIR                                349           5
# FIREARMS RESTRAINING ORDER (FIREARMS RO)                 906           4
# FAILURE TO DISPERSE                                      884           3
# DISHONEST EMPLOYEE ATTEMPTED THEFT                       445           2
# INCITING A RIOT                                          882           1
# Length: 138, dtype: int64
# Most common crime type observed is:   VEHICLE - STOLEN    87354
# Name: Crm Cd Desc, dtype: int64

# %%
# Trend over time of vehicle stolen by year
vehicle_stolen = crime_df[crime_df['Crm Cd Desc']=='VEHICLE - STOLEN'].index.value_counts().reset_index()
vehicle_stolen.columns = ['Date', 'crime_count']

# %%
vehicle_stolen['Date']= pd.to_datetime(vehicle_stolen['Date'])
vehicle_stolen.set_index('Date',inplace=True)

# %%
vehicle_stolen.resample('MS').mean().plot(kind='line')
plt.title('Vehicle Stolen Crime Trend')
plt.show()

# %%
# 4. Regional Differences
region_df = crime_df.groupby('AREA NAME')['DR_NO'].count().reset_index()
region_df.columns=['Area','Count']
region_df['Latitude']=crime_df.groupby('AREA NAME')['LAT'].median().reset_index()['LAT']
region_df['Longitude']=crime_df.groupby('AREA NAME')['LON'].median().reset_index()['LON']
region_df
# Out:
#            Area  Count  Latitude  Longitude
# 0   77th Street  51505   33.9766  -118.2937
# 1       Central  54815   34.0462  -118.2503
# 2    Devonshire  33103   34.2471  -118.5361
# 3      Foothill  27211   34.2528  -118.3929
# 4        Harbor  33771   33.7765  -118.2880
# 5    Hollenbeck  30642   34.0505  -118.2060
# 6     Hollywood  43249   34.0998  -118.3295
# 7       Mission  32449   34.2392  -118.4517
# 8   N Hollywood  40490   34.1700  -118.3823
# 9        Newton  40751   34.0089  -118.2620
# 10    Northeast  35209   34.1060  -118.2467
# 11      Olympic  41135   34.0607  -118.3004
# 12      Pacific  47721   33.9873  -118.4215
# 13      Rampart  38154   34.0609  -118.2747
# 14    Southeast  41613   33.9406  -118.2695
# 15    Southwest  45661   34.0202  -118.3119
# 16      Topanga  33097   34.1915  -118.6003
# 17     Van Nuys  34615   34.1817  -118.4487
# 18      West LA  37417   34.0484  -118.4419
# 19  West Valley  34129   34.1903  -118.5253
# 20     Wilshire  38655   34.0625  -118.3515

# %%
heat_m = folium.Map(location=[34.0579, -118.3205], zoom_start=9.5) 
for crime_col, crime_row in region_df.iterrows():
    folium.CircleMarker(
        location=[crime_row['Latitude'], crime_row['Longitude']],
        radius=crime_row['Count']*0.00075,
        color='yellow',
        fill_color='red',
        fill_opacity=0.3,
    ).add_to(heat_m)

display(heat_m) #show map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d0127a9dfe89bb8f6b49ee4c26844d4b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d0127a9dfe89bb8f6b49ee4c26844d4b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d0127a9dfe89bb8f6b49ee4c26844d4b = L.map(
#                 &quot;map_d0127a9dfe89bb8f6b49ee4c26844d4b&quot;,
#                 {
#                     center: [34.0579, -118.3205],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_738485f92936ccf946e5c9495b2113df = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d0127a9dfe89bb8f6b49ee4c26844d4b);
#
#
#             var circle_marker_7dbc22d06e0d99d0f9b8c145888f5212 = L.circleMarker(
#                 [33.9766, -118.2937],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 38.628750000000004, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d0127a9dfe89bb8f6b49ee4c26844d4b);
#
#
#             var circle_marker_29b27dbe2109897f5c5353e4c1c0f2d3 = L.circleMarker(
#                 [34.0462, -118.2503],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 41.11125, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d0127a9dfe89bb8f6b49ee4c26844d4b);
#
#
#             var circle_marker_6a39062fefaad9bc2325fd1deea87b9d = L.circleMarker(
#                 [34.2471, -118.5361],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 24.82725, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d0127a9dfe89bb8f6b49ee4c26844d4b);
#
#
#             var circle_marker_634a7658ab3a5c71824954ee7a0fa90b = L.circleMarker(
#                 [34.2528, -118.3929],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20.40825, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d0127a9dfe89bb8f6b49ee4c26844d4b);
#
#
#             var circle_marker_591e17f3912ad8a237ff620e7c649e9a = L.circleMarker(
#                 [33.7765, -118.288],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 25.32825, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d0127a9dfe89bb8f6b49ee4c26844d4b);
#
#
#             var circle_marker_50016ed7b1e0de42bbeb95f7c8ab5d85 = L.circleMarker(
#                 [34.0505, -118.206],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 22.9815, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d0127a9dfe89bb8f6b49ee4c26844d4b);
#
#
#             var circle_marker_7f50c51ebb06c206891874261cf355ee =

# %%
sns.barplot(data=region_df, x='Count', y='Area', order=region_df.sort_values('Count')['Area'])
# Out:
# <Axes: xlabel='Count', ylabel='Area'>

# %%
# 5. Correlation with economic factors
yearly_economic_data_la = pd.DataFrame({'year1':['2020','2021','2022','2023'],
                                       'mean_income':[112834,106931,120272,129000],
                                       'median_income':[76367,69778,82516,98200],
                                       'emmigration':[20259,40786,33235,30200],
                                       'homeless':[66436,80436,81235,75518],
                                       'unemployement_rate':[6.1,6,4.2,5.1],
                                       'inflation':[1.2,3.8,7.4,3.8]})
yearly_economic_data_la
# Out:
#   year1  mean_income  median_income  emmigration  homeless  \
# 0  2020       112834          76367        20259     66436
# 1  2021       106931          69778        40786     80436
# 2  2022       120272          82516        33235     81235
# 3  2023       129000          98200        30200     75518
#
#    unemployement_rate  inflation
# 0                 6.1        1.2
# 1                 6.0        3.8
# 2                 4.2        7.4
# 3                 5.1        3.8

# %%
yearly_crime = crime_count.resample('Y').sum().reset_index()
yearly_crime.columns = ['year','crime_count']
yearly_crime['year']=yearly_crime['year'].dt.year
yearly_crime
# Out:
#    year  crime_count
# 0  2020       199328
# 1  2021       209240
# 2  2022       234049
# 3  2023       172775

# %%
economic_crime_data = pd.concat([yearly_crime,yearly_economic_data_la],axis = 1)
economic_crime_data.drop('year1',axis=1,inplace=True)
economic_crime_data['crime_rate']= (economic_crime_data['crime_count']/economic_crime_data['crime_count'].sum())*10
economic_crime_data
# Out:
#    year  crime_count  mean_income  median_income  emmigration  homeless  \
# 0  2020       199328       112834          76367        20259     66436
# 1  2021       209240       106931          69778        40786     80436
# 2  2022       234049       120272          82516        33235     81235
# 3  2023       172775       129000          98200        30200     75518
#
#    unemployement_rate  inflation  crime_rate
# 0                 6.1        1.2    2.444567
# 1                 6.0        3.8    2.566128
# 2                 4.2        7.4    2.870386
# 3                 5.1        3.8    2.118919

# %%
fig, ax = plt.subplots(1,1)
ax.plot(economic_crime_data['year'],economic_crime_data['crime_count'],label = 'Crime Count')
ax.plot(economic_crime_data['year'],economic_crime_data['median_income'], label = 'Median Income')
ax.plot(economic_crime_data['year'],economic_crime_data['emmigration'], label = 'Emmigration')
ax.plot(economic_crime_data['year'],economic_crime_data['homeless'], label = 'Homeless')
ax.legend()

# %%
fig, ax = plt.subplots(1,1)
ax.plot(economic_crime_data['year'],economic_crime_data['unemployement_rate'],label = 'Unemployement Rate')
ax.plot(economic_crime_data['year'],economic_crime_data['inflation'], label = 'Inflation')
ax.plot(economic_crime_data['year'],economic_crime_data['crime_rate'], label = 'Crime Rate')
ax.legend()

# %%
# 6.Day of week:
dup = crime_df.reset_index()
dup['Day of Week'] = dup['DATE OCC'].dt.day_name()
crimes_DOW = dup.groupby(['year occured','Day of Week']).size().groupby('Day of Week').mean().reset_index()
crimes_DOW.columns=['Day','Average crimes per day of week']
crimes_DOW
# Out:
#          Day  Average crimes per day of week
# 0     Friday                        31100.75
# 1     Monday                        28873.25
# 2   Saturday                        29780.75
# 3     Sunday                        28438.75
# 4   Thursday                        28760.75
# 5    Tuesday                        27947.25
# 6  Wednesday                        28946.50

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=dup, x='Day of Week', hue='year occured', palette='viridis',
              order=['Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday'])
y=crimes_DOW['Average crimes per day of week']
plt.plot(y, marker='.', color='black', linestyle='--', label='Average')
plt.legend(title='Year', loc='center left', bbox_to_anchor=(1, 0.85))
plt.grid()
plt.xlabel("Day of week")
plt.ylabel("Count of crimes")
plt.title("Crimes grouped by Day of week and year")
plt.show()

# %%
# 7. Impact of major event
# Policy change effects
fig, ax = plt.subplots(1,1, figsize= (10,6))

avg = monthly_crime_count['crime_count'].sum()/len(monthly_crime_count)
avg = [avg]*len(monthly_crime_count)

ax.plot(monthly_crime_count, label ='Monthly Crime Count')
ax.plot(monthly_crime_count.index,avg,linestyle= '--', label='Avg Crime')

fig.suptitle('Los Angeles Crime Trend')

ax.legend()

# %%
# 8. Outlier and unusual patterns
crime_df['Vict Sex'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
sns.boxplot(data=crime_df, x='Vict Age')
# Out:
# <Axes: xlabel='Vict Age'>

# %%
# 9. Demographic Factors

# %%
crime_df['Vict Sex'].value_counts().plot(kind = 'bar') # Male Victims > Female
# Out:
# <Axes: >

# %%
a = sns.catplot(data=crime_df,x='Vict Descent', hue = 'Vict Sex',kind = 'count', height=5, aspect=1.8,
           hue_order=crime_df['Vict Sex'].value_counts()[0:2].index,
           order=crime_df['Vict Descent'].value_counts(ascending=False)[0:6].index)
a.set_xticklabels(['Latinx','Unknown','White','Black','Other Asian','Asian'])

# %%
# Analysing Victim Descent

descent_count = crime_df['Vict Descent'].value_counts()
descent_prop = descent_count/descent_count.sum()
descent_prop
# Out:
# H    0.307079
# X    0.227346
# W    0.203964
# B    0.142647
# O    0.079191
# A    0.021900
# K    0.005309
# F    0.004159
# C    0.003810
# J    0.001392
# V    0.001024
# I    0.000946
# Z    0.000504
# P    0.000267
# U    0.000204
# D    0.000074
# G    0.000069
# L    0.000060
# S    0.000055
# Name: Vict Descent, dtype: float64

# %%
finalised_categories = descent_prop[descent_prop>0.1] # selecting only categories that have prop > 0.1
finalised_categories['Other']= descent_prop[descent_prop<=0.1].sum()

# %%
desc_legend = {'H': 'Hispanic', 'W': 'White', 'B': 'Black', 'O': 'Other', 'A': 'Asian', 
               'F': 'Pacific Islander', 'K': 'Korean', 'C': 'Chinese', 'U': 'Unknown', 
               'I': 'American Indian', 'J': 'Japanese', 'P': 'Filipino', 'V': 'Vietnamese', 
               'Z': 'Asian Indian', 'G': 'Guamanian', 'S': 'Samoan', 'D': 'Cambodian', 
               'L': 'Laotian', 'X': 'Other Asian', 'R': 'Other Pacific Islander'}
lab = [desc_legend[i] if i in desc_legend.keys() else i for i in finalised_categories.index.values]

# %%
plt.pie(finalised_categories,labels=lab, autopct='%1.1f%%')
plt.show()

# %%
# Modelling

# %%
monthly_crime_count.head()
# Out:
#             crime_count
# Date
# 2020-01-01   595.903226
# 2020-02-01   594.620690
# 2020-03-01   521.000000
# 2020-04-01   522.366667
# 2020-05-01   554.419355

# %%
fig, ax = plt.subplots(1,1, figsize= (10,6))

avg = monthly_crime_count['crime_count'].sum()/len(monthly_crime_count)
avg = [avg]*len(monthly_crime_count)

ax.plot(monthly_crime_count, label ='Monthly Crime Count')
ax.plot(monthly_crime_count.index,avg,linestyle= '--', label='Avg Crime')

fig.suptitle('Los Angeles Crime Trend')

ax.legend()

# %%
# Rolling average to check whether the mean is staying stationary 
roll_mean = monthly_crime_count.rolling(window = 4, center = False).mean()

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(monthly_crime_count, color='blue', label='Original')
plt.plot(roll_mean, color='black', label='Rolling Mean')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation')
plt.show(block=False)

# %%
# So we can see mean is not constant

# %%
# Checking partial auto correlation
plot_pacf(monthly_crime_count,lags=12)

# %%
# Base model

# %%
arima = ARIMA(monthly_crime_count, order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
arima_fit = arima.fit()
arima_fit.summary()
# Out:
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                     SARIMAX Results
# ========================================================================================
# Dep. Variable:                      crime_count   No. Observations:                   46
# Model:             ARIMA(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood                -167.175
# Date:                          Wed, 01 Nov 2023   AIC                            344.349
# Time:                                  22:27:23   BIC                            351.832
# Sample:                              01-01-2020   HQIC                           346.867
#                                    - 10-01-2023
# Covariance Type:                            opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4925      1.059      0.465      0.642      -1.584       2.569
# ma.L1         -0.0611      1.036     -0.059      0.953      -2.092       1.969
# ar.S.L12      -0.4749      1.298     -0.366      0.714      -3.019       2.069
# ma.S.L12       0.0914      1.594      0.057      0.954      -3.032       3.215
# sigma2      1371.2181    415.852      3.297      0.001     556.164    2186.273
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                65.58
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.70   Skew:                            -1.81
# Prob(H) (two-sided):                  0.02   Kurtosis:                         8.88
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
monthly_crime_count.head()
# Out:
#             crime_count
# Date
# 2020-01-01   595.903226
# 2020-02-01   594.620690
# 2020-03-01   521.000000
# 2020-04-01   522.366667
# 2020-05-01   554.419355

# %%
monthly_crime_count.tail()
# Out:
#             crime_count
# Date
# 2023-06-01   612.033333
# 2023-07-01   630.032258
# 2023-08-01   624.709677
# 2023-09-01   588.266667
# 2023-10-01   426.222222

# %%
X = monthly_crime_count.index
y = monthly_crime_count['crime_count']

train = monthly_crime_count.loc['2020-01-01':'2022-12-31']
test = monthly_crime_count.loc['2023-01-01' : ]

X_train, X_test = train.index , test.index
y_train, y_test = train['crime_count'] , test['crime_count']

# %%
import itertools

# Define the p, d and q parameters to take any value between 0 and 2
p = d = q = range(0, 3)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
pdqs = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

# %%
# Gridsearch to find best parameters

ans = []
for comb in pdq:
    for combs in pdqs:
        try:
            mod = sm.tsa.statespace.SARIMAX(y_train,
                                            order=comb,
                                            seasonal_order=combs,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            output = mod.fit()
            ans.append([comb, combs, output.aic])
            print('ARIMA {} x {}12 : AIC Calculated ={}'.format(comb, combs, output.aic))
        except:
            continue
# Out:
#  This problem is unconstrained.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
#  This problem is unconstrained.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
#  This problem is unconstrained.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.57943D+00    |proj g|=  1.21085D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      0      1      0     0     0   1.211D-06   7.579D+00
#   F =   7.5794304907122081
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (0, 0, 0, 12)12 : AIC Calculated =547.718995331279
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.47644D+01    |proj g|=  4.92862D+01
#
# At iterate    5    f=  7.00849D+00    |proj g|=  1.35190D+00
#
# At iterate   10    f=  5.02251D+00    |proj g|=  4.64143D-02
#
# At iterate   15    f=  4.97116D+00    |proj g|=  5.97139D-04
#
# At iterate   20    f=  4.93931D+00    |proj g|=  7.05449D-03
#
# At iterate   25    f=  4.84021D+00    |proj g|=  1.94431D-02
#
# At iterate   30    f=  4.80638D+00    |proj g|=  5.11990D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     32     44      1     0     0   2.651D-06   4.806D+00
#   F =   4.8063570556466226
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (0, 0, 1, 12)12 : AIC Calculated =350.0577080065568
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.97423D+01    |proj g|=  1.18554D+00
#
# At iterate    5    f=  2.34956D+00    |proj g|=  4.14288D-04
#
# At iterate   10    f=  2.34943D+00    |proj g|=  5.47915D-04
#
# At iterate   15    f=  2.34437D+00    |proj g|=  6.59757D-03
#
# At iterate   20    f=  2.33118D+00    |proj g|=  4.70092D-03
#
# At iterate   25    f=  2.32693D+00    |proj g|=  1.86525D-03
#
# At iterate   30    f=  2.32633D+00    |proj g|=  2.00862D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     30     46      1     0     0   2.009D-06   2.326D+00
#   F =   2.3263306309668215
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (0, 0, 2, 12)12 : AIC Calculated =173.49580542961115
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.63339D+00    |proj g|=  5.87798D-03
#
# At iterate    5    f=  3.60221D+00    |proj g|=  3.73634D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      5      6      1     0     0   3.736D-06   3.602D+00
#   F =   3.6022099251026551
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (0, 1, 0, 12)12 : AIC Calculated =261.3591146073912
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.88086D+00    |proj g|=  1.69886D-01
#
# At iterate    5    f=  1.75447D+00    |proj g|=  1.01463D-04
#
# At iterate   10    f=  1.75445D+00    |proj g|=  1.96706D-03
#
# At iterate   15    f=  1.75333D+00    |proj g|=  1.39566D-03
#
# At iterate   20    f=  1.75330D+00    |proj g|=  1.74083D-08
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     20     26      1     0     0   1.741D-08   1.753D+00
#   F =   1.7533002224295366
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (0, 1, 1, 12)12 : AIC Calculated =130.23761601492663
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (0, 1, 2, 12)12 : AIC Calculated =6.0
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.89430D+00    |proj g|=  1.04523D-02
# ARIMA (0, 0, 0) x (0, 2, 0, 12)12 : AIC Calculated =130.45771080012017
#
# At iterate    5    f=  1.78421D+00    |proj g|=  1.21692D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      7      9      1     0     0   6.095D-07   1.784D+00
#   F =   1.7841348722238912
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (0, 2, 1, 12)12 : AIC Calculated =4.0
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (0, 2, 2, 12)12 : AIC Calculated =6.0
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.54082D+00    |proj g|=  4.34904D-04
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      1     17      1     0     0   4.349D-04   3.541D+00
#   F =   3.5408197208220673
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA (0, 0, 0) x (1, 0, 0, 12)12 : AIC Calculated =258.93901989918885
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.47644D+01    |proj g|=  9.41236D+01
#
# At iterate    5    f=  3.42447D+00    |proj g|=  8.28291D-01
#
# At iterate   10    f=  3.27565D+00    |proj g|=  9.30787D-02
#
# At iterate   15    f=  3.27559D+00    |proj g|=  2.58850D-02
#
# At iterate   20    f=  3.27333D+00    |proj g|=  3.90838D-01
#
# At iterate   25    f=  3.21675D+00    |proj g|=  2.75180D+00
#
# At iterate   30    f=  3.20191D+00    |proj g|=  2.78314D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     32     52      1     0     0   6.638D-05   3.202D+00
#   F =   3.2019133944647815
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA (0, 0, 0) x (1, 0, 1, 12)12 : AIC Calculated =236.53776440146427
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.97423D+01    |proj g|=  5.05115D+01
#
# At iterate    5    f=  1.56988D+00    |proj g|=  6.90255D-03
#
# At iterate   10    f=  1.56973D+00    |proj g|=  5.04639D-02
#
# At iterate   15    f=  1.56966D+00    |proj g|=  3.67144D-02
#
# At iterate   20    f=  1.56698D+00    |proj g|=  3.54842D-01
#
# At iterate   25    f=  1.56244D+00    |proj g|=  2.37448D-03
#
# At iterate   30    f=  1.56231D+00    |proj g|=  2.11022D-02
#
# At iterate   35    f=  1.56212D+00    |proj g|=  4.02876D-02
#
# At iterate   40    f=  1.56195D+00    |proj g|=  3.12955D-02
#
# At iterate   45    f=  1.56192D+00    |proj g|=  3.57105D-04
#
# At iterate   50    f=  1.56192D+00    |proj g|=  3.91128D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     50     59      1     0     0   3.911D-03   1.562D+00
#   F =   1.5619195025425234
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ARIMA (0, 0, 0) x (1, 0, 2, 12)12 : AIC Calculated =120.45820418306168
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.91388D+00    |proj g|=  9.72222D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   9.722D-07   1.914D+00
#   F =   1.9138839577684996
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (1, 1, 0, 12)12 : AIC Calculated =141.79964495933197
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.88086D+00    |proj g|=  1.69886D-01
#
# At iterate    5    f=  1.76257D+00    |proj g|=  5.17305D-04
#  This problem is unconstrained.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/mlemodel.py:1234: RuntimeWarning: invalid value encountered in divide
#   np.inner(score_obs, score_obs) /
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
# At iterate   10    f=  1.76257D+00    |proj g|=  3.75636D-04
#
# At iterate   15    f=  1.76177D+00    |proj g|=  1.85827D-02
#
# At iterate   20    f=  1.75980D+00    |proj g|=  7.73987D-03
#
# At iterate   25    f=  1.75792D+00    |proj g|=  4.05683D-03
#
# At iterate   30    f=  1.75669D+00    |proj g|=  1.23312D-03
#
# At iterate   35    f=  1.75542D+00    |proj g|=  2.07172D-03
#
# At iterate   40    f=  1.75473D+00    |proj g|=  3.45756D-03
#
# At iterate   45    f=  1.75440D+00    |proj g|=  9.76494D-04
#
# At iterate   50    f=  1.75398D+00    |proj g|=  2.26210D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     50     71      1     0     0   2.262D-03   1.754D+00
#   F =   1.7539799746010192
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ARIMA (0, 0, 0) x (1, 1, 1, 12)12 : AIC Calculated =132.28655817127338
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (1, 1, 2, 12)12 : AIC Calculated =8.0
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (1, 2, 0, 12)12 : AIC Calculated =4.0
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (1, 2, 1, 12)12 : AIC Calculated =6.0
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (1, 2, 2, 12)12 : AIC Calculated =8.0
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.59092D+00    |proj g|=  6.71002D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      1     15      1     0     0   6.709D-04   1.591D+00
#   F =   1.5909246494197071
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA (0, 0, 0) x (2, 0, 0, 12)12 : AIC Calculated =120.54657475821891
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.12548D+01    |proj g|=  5.29859D+01
#
# At iterate    5    f=  1.65655D+00    |proj g|=  2.14831D-02
#
# At iterate   10    f=  1.65624D+00    |proj g|=  3.68813D-02
#
# At iterate   15    f=  1.65451D+00    |proj g|=  3.68902D-01
#
# At iterate   20    f=  1.59392D+00    |proj g|=  1.81190D-01
#
# At iterate   25    f=  1.59092D+00    |proj g|=  1.13421D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     26     28      1     0     0   1.724D-06   1.591D+00
#   F =   1.5909246725251711
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (2, 0, 1, 12)12 : AIC Calculated =122.54657642181232
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.97423D+01    |proj g|=  5.05115D+01
#
# At iterate    5    f=  1.50204D+00    |proj g|=  2.33375D-01
#
# At iterate   10    f=  1.49733D+00    |proj g|=  4.86788D-03
#
# At iterate   15    f=  1.49702D+00    |proj g|=  5.15299D-02
#
# At iterate   20    f=  1.47454D+00    |proj g|=  1.61651D-01
# ARIMA (0, 0, 0) x (2, 0, 2, 12)12 : AIC Calculated =110.62088543805703
#
# At iterate   25    f=  1.39769D+00    |proj g|=  7.70160D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     29     41      1     0     0   1.191D-05   1.398D+00
#   F =   1.3975122977507921
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (2, 1, 0, 12)12 : AIC Calculated =6.0
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/mlemodel.py:1234: RuntimeWarning: invalid value encountered in divide
#   np.inner(score_obs, score_obs) /
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/mlemodel.py:1234: RuntimeWarning: invalid value encountered in divide
#   np.inner(score_obs, score_obs) /
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
# ARIMA (0, 0, 0) x (2, 1, 1, 12)12 : AIC Calculated =8.0
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (2, 1, 2, 12)12 : AIC Calculated =10.0
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (2, 2, 0, 12)12 : AIC Calculated =6.0
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (2, 2, 1, 12)12 : AIC Calculated =8.0
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (2, 2, 2, 12)12 : AIC Calculated =10.0
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.17040D+00    |proj g|=  4.04617D-01
#
# At iterate    5    f=  7.04718D+00    |proj g|=  1.14085D-03
#
# At iterate   10    f=  7.04314D+00    |proj g|=  8.44233D-02
#
# At iterate   15    f=  6.90912D+00    |proj g|=  6.18579D-01
#
# At iterate   20    f=  6.77150D+00    |proj g|=  3.12674D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     20     28      1     0     0   3.127D-06   6.771D+00
#   F =   6.7714967910093815
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 1) x (0, 0, 0, 12)12 : AIC Calculated =491.5477689526755
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.65735D+00    |proj g|=  2.82555D-01
#
# At iterate    5    f=  4.55039D+00    |proj g|=  1.13466D-03
#
# At iterate   10    f=  4.55027D+00    |proj g|=  1.07442D-02
#
# At iterate   15    f=  4.52381D+00    |proj g|=  2.58607D-01
#
# At iterate   20    f=  4.28283D+00    |proj g|=  5.98102D-02
#
# At iterate   25    f=  4.23517D+00    |proj g|=  1.23371D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     28     43      1     0     0   2.939D-06   4.235D+00
#   F =   4.2350262658276794
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 1) x (0, 0, 1, 12)12 : AIC Calculated =310.9218911395929
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.12880D+00    |proj g|=  1.37948D-01
#  This problem is unconstrained.
#  This problem is unconstrained.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
# At iterate    5    f=  2.08052D+00    |proj g|=  3.24784D-04
#
# At iterate   10    f=  2.08045D+00    |proj g|=  3.78844D-03
#
# At iterate   15    f=  2.07158D+00    |proj g|=  5.03311D-02
#
# At iterate   20    f=  1.98356D+00    |proj g|=  4.00721D-02
#
# At iterate   25    f=  1.97203D+00    |proj g|=  8.48453D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     29     32      1     0     0   5.077D-06   1.972D+00
#   F =   1.9720159557438406
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 1) x (0, 0, 2, 12)12 : AIC Calculated =149.98514881355652
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.29242D+00    |proj g|=  9.39482D-02
#
# At iterate    5    f=  3.28227D+00    |proj g|=  1.78697D-02
#
# At iterate   10    f=  3.23884D+00    |proj g|=  2.26497D-01
#
# At iterate   15    f=  3.20967D+00    |proj g|=  1.68292D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     17     19      1     0     0   2.339D-07   3.210D+00
#   F =   3.2096735361090243
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 1) x (0, 1, 0, 12)12 : AIC Calculated =235.09649459984976
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.51585D+00    |proj g|=  3.26498D-02
#
# At iterate    5    f=  1.50872D+00    |proj g|=  1.71359D-03
#
# At iterate   10    f=  1.50003D+00    |proj g|=  3.62302D-02
#
# At iterate   15    f=  1.49133D+00    |proj g|=  5.71453D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     17     25      1     0     0   6.154D-07   1.491D+00
#   F =   1.4913340470825323
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 1) x (0, 1, 1, 12)12 : AIC Calculated =113.37605138994232
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 1) x (0, 1, 2, 12)12 : AIC Calculated =8.0
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.56742D+00    |proj g|=  2.74344D-01
#  This problem is unconstrained.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
#  This problem is unconstrained.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
# At iterate    5    f=  1.52215D+00    |proj g|=  2.13131D-04
#
# At iterate   10    f=  1.52212D+00    |proj g|=  4.88652D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     14     17      1     0     0   3.206D-06   1.522D+00
#   F =   1.5220841293680665
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 1) x (0, 2, 0, 12)12 : AIC Calculated =113.59005731450078
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 1) x (0, 2, 1, 12)12 : AIC Calculated =6.0
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 1) x (0, 2, 2, 12)12 : AIC Calculated =8.0
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.87036D+00    |proj g|=  6.76113D-03
#
# At iterate    5    f=  4.86942D+00    |proj g|=  5.31309D-03
#
# At iterate   10    f=  4.83328D+00    |proj g|=  1.09831D-01
#
# At iterate   15    f=  3.99889D+00    |proj g|=  1.12087D+00
#
# At iterate   20    f=  3.37082D+00    |proj g|=  1.41622D+00
#
# At iterate   25    f=  3.35064D+00    |proj g|=  3.72004D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
# ...
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (2, 2, 2) x (1, 1, 2, 12)12 : AIC Calculated =16.0
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (2, 2, 2) x (1, 2, 0, 12)12 : AIC Calculated =12.0
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (2, 2, 2) x (1, 2, 1, 12)12 : AIC Calculated =14.0
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
#  This problem is unconstrained.
# ARIMA (2, 2, 2) x (1, 2, 2, 12)12 : AIC Calculated =16.0
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.02612D+00    |proj g|=  1.94146D-01
#
# At iterate    5    f=  9.46351D-01    |proj g|=  1.01659D-01
#
# At iterate   10    f=  9.35478D-01    |proj g|=  4.39690D-02
#
# At iterate   15    f=  9.34127D-01    |proj g|=  7.35921D-03
#
# At iterate   20    f=  9.32582D-01    |proj g|=  1.37872D-02
#
# At iterate   25    f=  9.14973D-01    |proj g|=  2.28888D-01
#
# At iterate   30    f=  9.05569D-01    |proj g|=  1.16716D-01
#
# At iterate   35    f=  9.03778D-01    |proj g|=  6.93153D-02
#
# At iterate   40    f=  9.00688D-01    |proj g|=  2.39371D-01
#
# At iterate   45    f=  8.96832D-01    |proj g|=  8.22396D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     47     61      1     0     0   9.522D-04   8.968D-01
#   F =  0.89682956191338015
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA (2, 2, 2) x (2, 0, 0, 12)12 : AIC Calculated =78.57172845776337
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.66620D-01    |proj g|=  1.06788D-01
#
# At iterate    5    f=  9.35826D-01    |proj g|=  2.78469D-02
#
# At iterate   10    f=  9.34442D-01    |proj g|=  1.64384D-02
#
# At iterate   15    f=  9.33427D-01    |proj g|=  2.96977D-02
#
# At iterate   20    f=  9.12697D-01    |proj g|=  9.36308D-02
#
# At iterate   25    f=  9.07396D-01    |proj g|=  1.61242D-02
#
# At iterate   30    f=  9.04875D-01    |proj g|=  7.06921D-03
#
# At iterate   35    f=  9.04863D-01    |proj g|=  9.14531D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     36     41      1     0     0   8.190D-05   9.049D-01
#   F =  0.90486274620359097
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA (2, 2, 2) x (2, 0, 1, 12)12 : AIC Calculated =81.15011772665855
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.47937D-01    |proj g|=  1.30950D-01
#
# At iterate    5    f=  8.23809D-01    |proj g|=  1.67411D-02
#
# At iterate   10    f=  8.21483D-01    |proj g|=  3.11182D-02
#
# At iterate   15    f=  8.17393D-01    |proj g|=  5.57990D-03
#
# At iterate   20    f=  8.12525D-01    |proj g|=  6.38393D-02
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
# At iterate   25    f=  7.87069D-01    |proj g|=  2.71941D-02
#
# At iterate   30    f=  7.86652D-01    |proj g|=  1.36236D-03
#
# At iterate   35    f=  7.86650D-01    |proj g|=  2.50679D-05
#
# At iterate   40    f=  7.86650D-01    |proj g|=  1.76138D-04
#
# At iterate   45    f=  7.86648D-01    |proj g|=  6.79588D-04
#
# At iterate   50    f=  7.86647D-01    |proj g|=  5.54149D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     57      1     0     0   5.541D-04   7.866D-01
#   F =  0.78664683489490961
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ARIMA (2, 2, 2) x (2, 0, 2, 12)12 : AIC Calculated =74.6385721124335
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (2, 2, 2) x (2, 1, 0, 12)12 : AIC Calculated =14.0
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (2, 2, 2) x (2, 1, 1, 12)12 : AIC Calculated =16.0
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (2, 2, 2) x (2, 1, 2, 12)12 : AIC Calculated =18.0
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (2, 2, 2) x (2, 2, 0, 12)12 : AIC Calculated =14.0
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (2, 2, 2) x (2, 2, 1, 12)12 : AIC Calculated =16.0
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (2, 2, 2) x (2, 2, 2, 12)12 : AIC Calculated =18.0
#  This problem is unconstrained.
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.

# %%
# best parameters
best_param = pd.DataFrame(ans,columns=['pdq','pdqs','aic'])
best_param.loc[best_param['aic'].idxmin()]
# Out:
# pdq         (0, 0, 0)
# pdqs    (0, 2, 1, 12)
# aic               4.0
# Name: 7, dtype: object

# %%
sarimax = sm.tsa.statespace.SARIMAX(y_train,
                                   order=(0,0,0),
                                   seasonal_order=(0,2,1,12))
model = sarimax.fit()
model.summary()
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.97148D+00    |proj g|=  9.20006D-03
#
# At iterate    5    f=  1.95844D+00    |proj g|=  8.50979D-05
#
# At iterate   10    f=  1.95838D+00    |proj g|=  1.66925D-03
#
# At iterate   15    f=  1.95805D+00    |proj g|=  5.16331D-04
#
# At iterate   20    f=  1.95797D+00    |proj g|=  5.65690D-05
#
# At iterate   25    f=  1.95796D+00    |proj g|=  5.36835D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     25     27      1     0     0   5.368D-06   1.958D+00
#   F =   1.9579560404956591
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# /Users/vikaskagawad/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  SARIMAX Results
# ==================================================================================
# Dep. Variable:                crime_count   No. Observations:                   36
# Model:             SARIMAX(0, 2, [1], 12)   Log Likelihood                 -70.486
# Date:                    Thu, 02 Nov 2023   AIC                            144.973
# Time:                            12:18:09   BIC                            145.943
# Sample:                        01-01-2020   HQIC                           144.614
#                              - 12-01-2022
# Covariance Type:                      opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.S.L12      -0.9556    359.683     -0.003      0.998    -705.921     704.010
# sigma2      3989.4361   1.44e+06      0.003      0.998   -2.81e+06    2.82e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   9.21   Jarque-Bera (JB):                 1.41
# Prob(Q):                              0.00   Prob(JB):                         0.49
# Heteroskedasticity (H):               0.27   Skew:                            -0.25
# Prob(H) (two-sided):                  0.24   Kurtosis:                         1.40
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
prediction = model.get_prediction(start='2023-01-01', end = '2023-10-01',dynamic=False)
prediction_confidence_int = prediction.conf_int()
prediction_confidence_int
# Out:
#             lower crime_count  upper crime_count
# 2023-01-01         446.138030         742.636149
# 2023-02-01         502.114235         798.612354
# 2023-03-01         544.041978         840.540097
# 2023-04-01         579.704340         876.202459
# 2023-05-01         562.308672         858.806791
# 2023-06-01         577.242539         873.740658
# 2023-07-01         540.473098         836.971217
# 2023-08-01         550.732892         847.231011
# 2023-09-01         554.775863         851.273982
# 2023-10-01         565.174286         861.672405

# %%
ax = monthly_crime_count['2022-01-01':].plot(kind='line')
prediction.predicted_mean.plot(ax=ax, label='Forecast', alpha=0.9)
ax.fill_between(prediction_confidence_int.index,prediction_confidence_int.iloc[:,0],
               prediction_confidence_int.iloc[:,1],color='r', alpha= 0.2)
ax.legend()

# %%
#RMSE
y_pred = prediction.predicted_mean
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("Root mean squared error of SARIMAX model is:",rmse)
# Out:
# Root mean squared error of SARIMAX model is: 121.85459777629833

# %%
# Future forecast
pred = model.get_forecast(steps=24)
pred_conf = pred.conf_int()

# %%
ax = monthly_crime_count.plot(kind='line')
pred.predicted_mean.plot(ax=ax, label='Forecast', alpha=0.9)
ax.fill_between(pred_conf.index,pred_conf.iloc[:,0],
               pred_conf.iloc[:,1],color='r', alpha= 0.2)
ax.legend()
